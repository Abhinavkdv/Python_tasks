# %%
# 1
num1 = int(input("Enter the number:"))
num2 = int(input("Enter the number:"))

print("Addition:",(num1+num2))
print("Sub:",(num1-num2))
print("Mul:",(num1*num2))
print("Div:",(num1/num2))

if num1<num2:
    print(f"{num2} is bigger")
elif num1>num2:
    print(f"{num1} is bigger")
else:
    print("Both are same")
# Out:
# Enter the number: 10
# Enter the number: 5
# Addition: 15
# Sub: 5
# Mul: 50
# Div: 2.0
# 10 is bigger

# %%
# 2
for i in range(1,50):
    if i == 40:
        break
    elif i%5==0:
        continue
    else:
        print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 11
# 12
# 13
# 14
# 16
# 17
# 18
# 19
# 21
# 22
# 23
# 24
# 26
# 27
# 28
# 29
# 31
# 32
# 33
# 34
# 36
# 37
# 38
# 39

# %%
# 3
tot=0
count =0
while True:
    n = int(input("Enter"))
    if n<0:
        print(f"total: {tot}")
        print(f"Avg: {tot/count}")
        break
    tot = tot+n
    count+=1
# Out:
# Enter 3
# Enter 4
# Enter 5
# Enter 1
# Enter 2
# Enter -3
# total: 15
# Avg: 3.0

# %%
# 4
for i in range(5,0,-1):
    print("*"*i)
    print()
# Out:
# *****
#
# ****
#
# ***
#
# **
#
# *

# %%
# 5
for i in range(1,6):
    res =1
    for j in range(1,i+1):
        res*=j
    print(f"factorial of {i} is  {res}")
# Out:
# factorial of 1 is  1
# factorial of 2 is  2
# factorial of 3 is  6
# factorial of 4 is  24
# factorial of 5 is  120

# %%
# 6
s = "Hello there"
print(s.upper())
print(s.count('a'))
print(s.replace(" ","-"))
print(s.startswith("Hello"))
# Out:
# HELLO THERE
# 0
# Hello-there
# True

# %%
# 7
li = [1,2,3,4,5]
li.append(6)
li.insert(6,7)
li.remove(6)
li.pop()
li.sort(reverse=True)
li.reverse()
li
# Out:
# [1, 2, 3, 4, 5]

# %%
# 8
dicts = {
    "Abhinav":98,
    "Aditya":89,
    "Sahil":81,
    "harsha":83
}
for i in dicts.keys():
    if dicts[i]>90:
        print(i)
# Out:
# Abhinav

# %%
# 9
set1 = {1,2,3,4,5}
set2 = {4,5,6,7,8}
print(set1.union(set2))
print(set1.intersection(set2))
print(set1.difference(set2))
set1.add(9)
print(set1)
set1.discard(9)
print(set1)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}
# {4, 5}
# {1, 2, 3}
# {1, 2, 3, 4, 5, 9}
# {1, 2, 3, 4, 5}

# %%
# 10
class Student:
    def __init__(self,name,marks):
        self.name=name
        self.__marks=marks

    def get_marks(self):
        return self.__marks

    def set_marks(self,value):
        if 0<= value <= 100:
            self.__marks=value
        else:
            print("marks should be b/w 0 to 100")

std = Student("Abhinav",98)
std.get_marks()
std.set_marks(89)
std.get_marks()
# Out:
# 89

# %%
# 11
class BankError(Exception):
    pass

class BankAccount:
    def __init__(self,name,bal):
        self.name=name
        self.__bal=bal

    def deposit(self,amt):
        if amt<0:
            raise BankError("Entered amount should be positive")
        self.__bal+=amt

    def withdraw(self,amt):
        if amt<0:
            raise BankError("Entered amount should be positive")
        elif self.__bal-amt<0:
            raise BankError("Negative balance")
        else:
            self.__bal-=amt

    def get_bal(self):
        return self.__bal


try:
    ba = BankAccount("Abhinav",20_000)
    print(ba.get_bal())
    
    ba.deposit(2000)
    print(ba.get_bal())
    
    ba.withdraw(2000)
    print(ba.get_bal())
except Exception as e:
    print(e)
# Out:
# 20000
# 22000
# 20000

# %%
# 12
class Employee:
    def __init__(self,company_name):
        self.company_name=company_name

obj1 = Employee("ABC company")
print(obj1.company_name)
obj2 = Employee("XYZ company")
print(obj2.company_name)
obj1.company_name = "ABCD company"
print(obj1.company_name)
# Out:
# ABC company
# XYZ company
# ABCD company

# %%
# 13
class Product:
    def __init__(self,name,price):
        self.name=name
        self.__price=price

    def get_price(self):
        return self.__price

    def set_price(self,price):
        if price<100:
            print("Price should be greater than or equal t0 100")
        else:
            self.__price=price

obj = Product("Pen",10)
print(obj.get_price())
obj.set_price(20)
obj.set_price(120)
print(obj.get_price())
# Out:
# 10
# Price should be greater than or equal t0 100
# 120

# %%
# 14
class Rectangle:
    def __init__(self,length,width):
        self.__length = length
        self.__width = width

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return (2*(self.__length + self.__width))

r = Rectangle(5,4)
print(r.area())
r.perimeter()
# Out:
# 20
# 18

# %%
# 15
class Person:
    def __init__(self,name):
        self.name=name

    def fun(self):
        print(self.name)

class Student(Person):
    def __init__(self,name,sid):
        super().__init__(name)
        self.sid=sid

s = Student("Abhinav",98)
s.fun()
# Out:
# Abhinav

# %%
# 16
class Person:
    def __init__(self,name):
        self.name=name

    def fun(self):
        pass

class Employee(Person):
    def __init__(self,name,eid):
        super().__init__(name)
        self.eid=eid

    def fun(self):
        print(self.name)

class Manager(Employee):
    def __init__(self,name,eid):
        super().__init__(name,eid)

    def fun(self):
        print(self.name)
        print(self.eid)

m = Manager("Abhinav",98)
m.fun()
e = Employee("Sahil",117)
e.fun()
# Out:
# Abhinav
# 98
# Sahil

# %%
# 17
class Animal:
    def sound(self):
        print("makes sound")

class Dog(Animal):
    def sound(self):
        print("bark")
    
class Cat(Animal):
    def sound(self):
        print("meow")

dog = Dog()
dog.sound()
cat = Cat()
cat.sound()
# Out:
# bark
# meow

# %%
# 18
from abc import ABC,abstractmethod
class Shape(ABC):

    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self,r):
        self.r=r

    def area(self):
        return (3.14 * (self.r**2))

class Square(Shape):
    def __init__(self,a):
        self.a=a

    def area(self):
        return (self.a**2)

c = Circle(5)
print(c.area())
s = Square(5)
print(s.area())
# Out:
# 78.5
# 25

# %%
# 19
class Father:
    def fun(self):
        print("This is father function")

class Mother:
    def fun(self):
        print("This is mother function")

class Child(Father,Mother):
    def fun(self):
        print("This is child function")

c = Child()
c.fun()
# Out:
# This is child function

# %%
# 20
class Calculator:

    def add(self,*args):
        if len(args)==2:
            return args[0]+args[1]
        else:
            return args[0]+args[1]+args[2]

c = Calculator()
print(c.add(2,3))
print(c.add(2,3,4,6))
# Out:
# 5
# 9

# %%
# 21
class Point:
    def __init__(self,x,y):
        self.x = x
        self.y = y

    def __add__(self,other):
        return Point(self.x + other.x , self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

p1 = Point(2,3)
p2 = Point(3,2)
p3 = p1+p2
print(p3)
# Out:
# (5, 5)

# %%
# 22
try:
    list1 = [2,0]
    # print(list1[0]/list1[1])
    # print(list1[3])
    list1[1] = int('abhi')

except (ZeroDivisionError) as e:
    print(e)
except (ValueError) as e:
    print("Value Error")
except (IndexError) as e:
    print(e)
# Out:
# Value Error

# %%
# 23
class InvalidAgeError(Exception):
    pass

class Voter:
    def __init__(self,name,age):
        if age < 18:
            raise InvalidAgeError("Not Eligible to vote")
        else:
            self.name=name
            self.age = age

try:
    abhi = Voter("Ahbinav",12)
except Exception as e:
    print(e)
# Out:
# Not Eligible to vote

# %%
# 24
try:
    file1 = open("data.txt","r")
    f = file1.readlines()
    count = 0
    for i in f:
        x = i.split(" ")
        # print(i)
        for j in x:
            # print(j)
            count+=1
    print(count)
    file1.close()
    
except Exception as e:
    print(e)
# Out:
# 8

# %%
# 25
try:
    file_name = str(input("Enter your file name:"))
    while True:
        opt = str(input("Enter your operation:"))
        if opt == "write":
            filew = open(file_name,"w")
            text = str(input("Enter your text:"))
            filew.write(text)
            filew.close()
        elif opt == "read":
            filer = open(file_name,"r")
            print(filer.read())
            filer.close()
        elif opt == "append":
            filea = open(file_name,"a")
            text = str(input("Enter your text:"))
            filea.write(text)
            filea.close()
        else:
            break

except Exception as e:
    print(e)
# Out:
# Enter your file name: text.txt
# Enter your operation: read
# hi
# Enter your operation: append
# Enter your text: there
# Enter your operation: read
# hithere
# Enter your operation: write
# Enter your text: hello
# Enter your operation: read
# hello
# Enter your operation: append
# Enter your text:  there
# Enter your operation: exit

# %%
# 26 
class EmptyList(Exception):
    pass
class Student:
    def __init__(self,mlist):
        self.__mlist=mlist

    def set_mlist(self,new_mlist):
        if len(new_mlist)==0:
            raise EmptyList("Empty List")
        for i in new_mlist:
            if 0 > i > 100:
                return "marks should be b/w 0 and 100"
        self.__mlist = new_mlist

    def get_mlist(self):
        for i in self.__mlist:
            print(f"{i} ",end="")

    def average(self):
        return sum(self.__mlist)/len(self.__mlist)

    def __gt__(self,other):
        return self.average() > other.average()

try:
    m1 = [10,20,30,40,60]
    m2 = [50,40,30,20,10]
    std1 = Student(m1)
    std2 = Student(m2)
    # std.set_mlist(m1)
    # std.get_mlist()
    if std1 > std2:
        print("Student 1 has a higher average")
    else:
        print("Student 2 has a higher average")

except Exception as e:
    print(e)
# Out:
# Student 1 has a higher average

# %%
class InsufficientBalance(Exception):
    pass


class BankSystem:
    file = "bank.txt"
    count = 0

    def __init__(self, name, bal):
        self.name = name
        self.bal = bal
        self.id = BankSystem.count + 1
        BankSystem.count += 1
        self.save()

    def save(self):
        try:
            with open(BankSystem.file, "r") as f:
                data = json.load(f)
        except (FileNotFoundError, json.JSONDecodeError):
            data = {}

        data[str(self.id)] = {
            "Name": self.name,
            "Balance": self.bal
        }

        with open(BankSystem.file, "w") as f:
            json.dump(data, f, indent=4)

    def deposit(self, amt):
        if amt <= 0:
            raise ValueError("Invalid amount")
        self.bal += amt
        self.save()
        print("Deposit Successful")

    def withdraw(self, amt):
        if amt <= 0:
            raise ValueError("Invalid amount")
        if amt > self.bal:
            raise InsufficientBalance("Insufficient Balance")
        self.bal -= amt
        self.save()
        print("Withdrawal Successful")

    def display(self):
        print("\nAccount Number :", self.id)
        print("Name           :", self.name)
        print("Balance        :", self.bal)


try:
    while True:
        print("\n1.Create 2.Deposit 3.Withdraw 4.Display 5.Exit")
        opt = input("Enter your option: ")

        if opt == "1":
            name = input("Enter your name: ")
            bal = int(input("Enter your balance: "))
            obj = BankSystem(name, bal)
            print("Your account number is", obj.id)

        elif opt == "2":
            amt = int(input("Enter amount: "))
            obj.deposit(amt)

        elif opt == "3":
            amt = int(input("Enter amount: "))
            obj.withdraw(amt)

        elif opt == "4":
            obj.display()

        elif opt == "5":
            break

        else:
            print("Invalid Option")

except (FileNotFoundError, ValueError, InsufficientBalance) as e:
    print(e)
except Exception as e:
    print(e)
# Out:
# 1.Create 2.Deposit 3.Withdraw 4.Display 5.Exit
# Enter your option:  1
# Enter your name:  abhinav
# Enter your balance:  20000
# Your account number is 1
#
# 1.Create 2.Deposit 3.Withdraw 4.Display 5.Exit
# Enter your option:  2
# Enter amount:  2000
# Deposit Successful
#
# 1.Create 2.Deposit 3.Withdraw 4.Display 5.Exit
# Enter your option:  4
# Account Number : 1
# Name           : abhinav
# Balance        : 22000
#
# 1.Create 2.Deposit 3.Withdraw 4.Display 5.Exit
# Enter your option:  3
# Enter amount:  10000
# Withdrawal Successful
#
# 1.Create 2.Deposit 3.Withdraw 4.Display 5.Exit
# Enter your option:  4
# Account Number : 1
# Name           : abhinav
# Balance        : 12000
#
# 1.Create 2.Deposit 3.Withdraw 4.Display 5.Exit
# Enter your option:  5

# %%
# 28
class StudentNotFound(Exception):
    pass

students = {}

while True:
    print("\n1.Add 2.Update 3.Delete 4.Display 5.Exit")
    ch = input("Enter choice: ")

    try:
        if ch == "1":
            name = input("Enter student name: ")
            marks = int(input("Enter marks: "))
            students[name] = marks
            print("Student Added")

        elif ch == "2":
            name = input("Enter student name: ")
            if name not in students:
                raise StudentNotFound("Student not found")
            students[name] = int(input("Enter new marks: "))
            print("Marks Updated")

        elif ch == "3":
            name = input("Enter student name: ")
            if name not in students:
                raise StudentNotFound("Student not found")
            del students[name]
            print("Student Deleted")

        elif ch == "4":
            if students:
                for name, marks in students.items():
                    print(name, ":", marks)
            else:
                print("No students found")

        elif ch == "5":
            break

        else:
            print("Invalid Choice")

    except ValueError:
        print("Enter valid marks")
    except StudentNotFound as e:
        print(e)
# Out:
# 1.Add 2.Update 3.Delete 4.Display 5.Exit
# Enter choice:  1
# Enter student name:  abhinav
# Enter marks:  98
# Student Added
#
# 1.Add 2.Update 3.Delete 4.Display 5.Exit
# Enter choice:  2
# Enter student name:  abhinav
# Enter new marks:  89
# Marks Updated
#
# 1.Add 2.Update 3.Delete 4.Display 5.Exit
# Enter choice:  1
# Enter student name:  aditya
# Enter marks:  89
# Student Added
#
# 1.Add 2.Update 3.Delete 4.Display 5.Exit
# Enter choice:  1
# Enter student name:  harsha
# Enter marks:  83
# Student Added
#
# 1.Add 2.Update 3.Delete 4.Display 5.Exit
# Enter choice:  4
# abhinav : 89
# aditya : 89
# harsha : 83
#
# 1.Add 2.Update 3.Delete 4.Display 5.Exit
# Enter choice:  3
# Enter student name:  abhinav
# Student Deleted
#
# 1.Add 2.Update 3.Delete 4.Display 5.Exit
# Enter choice:  4
# aditya : 89
# harsha : 83
#
# 1.Add 2.Update 3.Delete 4.Display 5.Exit
# Enter choice:  5
