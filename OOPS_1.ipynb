# %%
#1
class Student:
    def __init__(self,name,age,mark):
        self.name=name
        self.age=age
        self.mark=mark
        
    def intro(self):
        print("Name:",name)
        print("Age:",age)
        print("marks:",mark)

std1 = Student("A",20,90)
std1.intro()
print("\n 2nd object")
std2 = Student("B",20,85)
std2.intro()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 14
#      11         print("marks:",mark)
#      13 std1 = Student("A",20,90)
# ---> 14 std1.intro()
#      15 print("\n 2nd object")
#      16 std2 = Student("B",20,85)
#
# Cell In[10], line 9, in Student.intro(self)
#       8 def intro(self):
# ----> 9     print("Name:",name)
#      10     print("Age:",age)
#      11     print("marks:",mark)
#
# NameError: name 'name' is not defined

# %%
# 2
class Employee:
    def __
