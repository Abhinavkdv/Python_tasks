# %%
# 1
class Person:
    
    def __init__(self,name,age):
        self.name=name
        self.age=age

class Student(Person):
    def __init__(self,name,age):
        super().__init__(name,age)

    def display(self):
        print(f"Name: {self.name}")
        print(f"Age: {self.age}")
        
class Teacher(Person):
    def __init__(self,name,age):
        super().__init__(name,age)

    def display(self):
        print(f"Name: {self.name}")
        print(f"Age: {self.age}")

st = Student("Abhinav",21)
t = Teacher("Sumit",26)

st.display()
t.display()
# Out:
# Name: Abhinav
# Age: 21
# Name: Sumit
# Age: 26

# %%
# 2
class Animal:
    def eat(self):
        print("Eating Food")

class Dog(Animal):
    pass
class Cat(Animal):
    pass

dog = Dog()
cat = Cat()

dog.eat()
cat.eat()
# Out:
# Eating Food
# Eating Food

# %%
# 3
class Vehicle:
    def start(self):
        print("Vechile started moving")

class Car(Vehicle):
    pass
class Bike(Vehicle):
    pass

car = Car()
bike = Bike()

car.start()
bike.start()
# Out:
# Vechile started moving
# Vechile started moving

# %%
# 4
class Shape:
    def area(self):
        print("Area of the shape")

class Circle:
    
    def __init__(self,r):
        self.r=r
        
    def area(self):
        print(f"Area of the Circle: {(3.14)*(self.r**2)} ")

class Rectangle:
    
    def __init__(self,l,b):
        self.l=l
        self.b=b
        
    def area(self):
        print(f"Area of the Rectangle: {self.l*self.b}")

circle = Circle(5)
rectangle = Rectangle(3,4)

circle.area()
rectangle.area()
# Out:
# Area of the Circle: 78.5
# Area of the Rectangle: 12

# %%
# 5
class Employee:

    def __init__(self,emp_id,salary):
        self.emp_id=emp_id
        self.salary=salary

class Manager(Employee):
    pass
class Developer(Employee):
    pass

manager = Manager(89,75_000)
dev = Developer(98,1_00_000)

print(manager.emp_id)
print(dev.salary)
# Out:
# 89
# 100000

# %%
# 6
class BankAccount:
    def deposit(self):
        print("This is deposit method")

class SavingsAccount(BankAccount):
    pass
class CurrentAccount(BankAccount):
    pass

sa = SavingsAccount()
ca = CurrentAccount()

sa.deposit()
ca.deposit()
# Out:
# This is deposit method
# This is deposit method

# %%
# 7
class Device:
    def turn_on(self):
        print("Turn on")
        
class Mobile(Device):
    pass

class Laptop(Device):
    pass

mobile = Mobile()
laptop = Laptop()

mobile.turn_on()
laptop.turn_on()
# Out:
# Turn on
# Turn on

# %%
# 8
class Sports:
    def play(self):
        print("playing")

class Cricket(Sports):
    pass
class Football(Sports):
    pass

cricket = Cricket()
football = Football()

cricket.play()
football.play()
# Out:
# playing
# playing

# %%
# 9
class Product:
    def __init__(self,price):
        self.price=price

class Electronics(Product):
    def __init__(self,price):
        super().__init__(price)

    def display(self):
        print(f"Price: {self.price}")

class Clothing(Product):
    def __init__(self,price):
        super().__init__(price)

    def display(self):
        print(f"Price: {self.price}")

e = Electronics(15_000)
c = Clothing(5_000)

e.display()
c.display()
# Out:
# Price: 15000
# Price: 5000

# %%
# 10
class Book:
    def __init__(self,b_name,b_author):
        self.b_name=b_name
        self.b_author=b_author

class Fiction(Book):
    def __init__(self,b_name,b_author):
        super().__init__(b_name,b_author)

    def display(self):
        print(f"Book Name: {self.b_name}")
        print(f"Book Author: {self.b_author}")

class NonFiction(Book):
    def __init__(self,b_name,b_author):
        super().__init__(b_name,b_author)

    def display(self):
        print(f"Book Name: {self.b_name}")
        print(f"Book Author: {self.b_author}")

f = Fiction("One Piece","E.Oda")
nf = NonFiction("Spy X Family","unknown")
f.display()
nf.display()
# Out:
# Book Name: One Piece
# Book Author: E.Oda
# Book Name: Spy X Family
# Book Author: unknown

# %%
# 11
class Account:
    def show_balance(self):
        print("Account balance is displayed")

class UserAccount(Account):
    pass

class AdminAccount(Account):
    pass

user = UserAccount()
admin = AdminAccount()
user.show_balance()
admin.show_balance()
# Out:
# Account balance is displayed
# Account balance is displayed

# %%
# 12
class Transport:
    def move(self):
        print("Transport is moving")

class Bus(Transport):
    pass

class Train(Transport):
    pass
    
bus = Bus()
train = Train()
bus.move()
train.move()
# Out:
# Transport is moving
# Transport is moving

# %%
# 13
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

class Student(Person):
    def __init__(self, name, age, roll_no):
        super().__init__(name, age)
        self.roll_no = roll_no

    def display(self):
        print("Name:", self.name)
        print("Age:", self.age)
        print("Roll No:", self.roll_no)

student1 = Student("Rahul", 20, 101)
student1.display()
# Out:
# Name: Rahul
# Age: 20
# Roll No: 101

# %%
# 14
class Animal:
    def sound(self):
        print("Animal making sound")

class Dog(Animal):
    def sound(self):
        print("Barking")

class Cat(Animal):
    def sound(self):
        print("Meow")

cat=Cat()
dog=Dog()
cat.sound()
dog.sound()
# Out:
# Meow
# Barking

# %%
# 15
class Vehicle:
    def __init__(self,brand):
        self.brand=brand

class Car(Vehicle):
    def __init__(self,brand,doors):
        super().__init__(brand)
        self.doors = doors

class Bike(Vehicle):
    def __init__(self,brand,engine_cc):
        super().__init__(brand)
        self.engine_cc = engine_cc

car = Car("BMW",2)
bike = Bike("Honda",150)

print(car.brand)
print(car.doors)
print(bike.brand)
print(bike.engine_cc)
# Out:
# BMW
# 2
# Honda
# 150

# %%
# 16
class Shape:
    def area(self):
        print("Area of shape")

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        print("Area of Circle:",(3.14)*self.radius**2)

class Square(Shape):
    def __init__(self, side):
        self.side = side

    def area(self):
        print("Area of Square:",self.side*self.side)

circle = Circle(5)
square = Square(4)
circle.area()
square.area()
# Out:
# Area of Circle: 78.5
# Area of Square: 16

# %%
# 17
class Employee:
    def get_details(self):
        pass

class Child1:
    def __init__(self,name,age):
        self.name=name
        self.age=age

    def get_details(self):
        print(self.name)
        print(self.age)

class Child2:
    def __init__(self,name,age):
        self.name=name
        self.age=age

    def get_details(self):
        print(self.name)
        print(self.age)

child1 = Child1("Abhi",21)
child2 = Child2("Sai",24)
child1.get_details()
child2.get_details()
# Out:
# Abhi
# 21
# Sai
# 24

# %%
# 18
class BankAccount:
    def __init__(self, balance):
        self.balance = balance

    def calculate_interest(self):
        pass

class SavingsAccount(BankAccount):
    def calculate_interest(self):
        print("Savings Interest:", self.balance * 0.05)

class CurrentAccount(BankAccount):
    def calculate_interest(self):
        print("Current Interest:", self.balance * 0.02)

savings = SavingsAccount(10000)
current = CurrentAccount(10000)
savings.calculate_interest()
current.calculate_interest()
# Out:
# Savings Interest: 500.0
# Current Interest: 200.0

# %%
# 19
class Device:
    def info(self):
        pass

class Phone(Device):
    def info(self):
        print("This is a Phone")

class Tablet(Device):
    def info(self):
        print("This is a Tablet")

phone = Phone()
tablet = Tablet()
phone.info()
tablet.info()
# Out:
# This is a Phone
# This is a Tablet

# %%
# 20
class Game:
    def start(self):
        print("Game Started")

class Chess(Game):
    def checkmate(self):
        print("Checkmate!")

class Ludo(Game):
    def roll_dice(self):
        print("Dice Rolled")

chess = Chess()
ludo = Ludo()
chess.start()
ludo.start()
chess.checkmate()
ludo.roll_dice()
# Out:
# Game Started
# Game Started
# Checkmate!
# Dice Rolled

# %%
# 21
class Person:
    def __init__(self, name):
        self.__name = name

    def get_name(self): 
        return self.__name

class Student(Person):
    def display(self):
        print("Name:", self.get_name())

student = Student("Abhinav")
student.display()
# Out:
# Name: Abhinav

# %%
# 22
class Animal:
    def sound(self):
        print("Animal makes a sound")

class Dog(Animal):
    def sound(self):
        print("Dog barks")

class Cat(Animal):
    def sound(self):
        print("Cat meows")
        
dog = Dog()
cat = Cat()
dog.sound()
cat.sound()
# Out:
# Dog barks
# Cat meows

# %%
# 23
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

class Student(Person):
    def __init__(self, name, age, marks):
        super().__init__(name, age)
        self.marks = marks

    def display(self):
        print("Student:", self.name, self.age, self.marks)

class Teacher(Person):
    def __init__(self, name, age, subject):
        super().__init__(name, age)
        self.subject = subject

    def display(self):
        print("Teacher:", self.name, self.age, self.subject)

class Staff(Person):
    def __init__(self, name, age, department):
        super().__init__(name, age)
        self.department = department

    def display(self):
        print("Staff:", self.name, self.age, self.department)

s = Student("Rahul", 20, 95)
t = Teacher("Anita", 35, "Python")
st = Staff("Ravi", 40, "Admin")
s.display()
t.display()
st.display()
# Out:
# Student: Rahul 20 95
# Teacher: Anita 35 Python
# Staff: Ravi 40 Admin

# %%
# 24
class Account:
    def __init__(self, balance):
        self.balance = balance

class Savings(Account):
    def interest(self):
        print("Interest:", self.balance * 0.05)

class Current(Account):
    def overdraft(self):
        print("Overdraft Available")

class FixedDeposit(Account):
    def maturity(self):
        print("Maturity Amount:", self.balance * 1.10)

s = Savings(10000)
c = Current(15000)
f = FixedDeposit(20000)
s.interest()
c.overdraft()
f.maturity()
# Out:
# Interest: 500.0
# Overdraft Available
# Maturity Amount: 22000.0

# %%
# 25
class Vehicle:
    def start(self):
        print("Vehicle Started")

class TwoWheeler(Vehicle):
    def helmet(self):
        print("Wear Helmet")

class FourWheeler(Vehicle):
    def seatbelt(self):
        print("Wear Seatbelt")

bike = TwoWheeler()
car = FourWheeler()
bike.start()
bike.helmet()
car.start()
car.seatbelt()
# Out:
# Vehicle Started
# Wear Helmet
# Vehicle Started
# Wear Seatbelt

# %%
# 26
class Animal:
    def eat(self):
        print("Animal eats food")

class Herbivore(Animal):
    def eat(self):
        print("Herbivore eats plants")

class Carnivore(Animal):
    def eat(self):
        print("Carnivore eats meat")

h = Herbivore()
c = Carnivore()
h.eat()
c.eat()
# Out:
# Herbivore eats plants
# Carnivore eats meat
