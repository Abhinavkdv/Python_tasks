# %%
students = ["Abhi","Sai","Ram","Pavan","Surya"]
print(students)
# Out:
# ['Abhi', 'Sai', 'Ram', 'Pavan', 'Surya']

# %%
numbers = [10,20,30,40,50]
print(type(numbers))
print(len(numbers))
# Out:
# <class 'list'>
# 5

# %%
data = []
data.append(10)
data.append(20)
data.append(30)
data
# Out:
# [10, 20, 30]

# %%
lst = [1,2,3]
lst.extend([4,5,6])
lst
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
data = [10,20,30,40]
data.insert(2,100)
data
# Out:
# [10, 20, 100, 30, 40]

# %%
data = [10,20,50,30,50]
data.remove(50)
data
# Out:
# [10, 20, 30, 50]

# %%
data = [5, 10, 15, 20]
data.pop()
data
# Out:
# [5, 10, 15]

# %%
data = [1, 2, 3, 4, 5]
data.clear()
data
# Out:
# []

# %%
data = [10, 15, 25, 30, 40]
data.index(25)
# Out:
# 2

# %%
data = [7, 2, 7, 5, 7, 8]
data.count(7)
# Out:
# 3

# %%
data = [45, 12, 78, 23, 56]
data.sort()
data
# Out:
# [12, 23, 45, 56, 78]

# %%
data = [45, 12, 78, 23, 56]
data.sort(reverse=True)
data
# Out:
# [78, 56, 45, 23, 12]

# %%
fruits = ["apple", "banana", "mango", "orange"]
fruits.reverse()
fruits
# Out:
# ['orange', 'mango', 'banana', 'apple']

# %%
original = [1, 2, 3, 4]
copy = original.copy()
copy.append(5)
print(original)
print(copy)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4, 5]

# %%
text = input("Enter:")
words = text.split()
print(words)
# Out:
# Enter: I love Python programming
# ['I', 'love', 'Python', 'programming']

# %%
data = [2,3,1,5,6]
data.extend([4,8,7])
# data.append(4)
data.sort(reverse=True)
data
# Out:
# [8, 7, 6, 5, 4, 3, 2, 1]

# %%
data = ["Python"]
data.pop()
len(data)
# Out:
# 0

# %%
citys = []
for i in range(5):
    city = input(f"Enter city{i+1}:")
    citys.append(city)

# %%
students = {"name":"Abhinav","age":21,"city":"Vizag"}
students
# Out:
# {'name': 'Abhinav', 'age': 21, 'city': 'Vizag'}

# %%
d = {"a": 1, "b": 2, "c": 3}
d.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
d = {"a": 1, "b": 2}
d.values()
# Out:
# dict_values([1, 2])

# %%
d = {"name": "Sumit", "age": 25}
d.get("name")
# Out:
# 'Sumit'

# %%
A = (1,2,3,4,5)
print(type(A))
len(A)
# Out:
# <class 'tuple'>
# 5

# %%
tup = (10,20,30,40,50)
tup.count(20)
# Out:
# 1

# %%
tup.index(40)
# Out:
# 3

# %%
my_dict = {}
my_dict["name"] = "Alice"
my_dict["Age"] = 21
my_dict["city"] = "Vizag"
print(my_dict)
# Out:
# {'name': 'Alice', 'Age': 21, 'city': 'Vizag'}

# %%
d = {"a": 1, "b": 2}
d.update({"c": 3, "d": 4})
d
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
student = {"name": "Rahul",  "age": 22, "city": "Delhi"}
student.pop("age")
student
# Out:
# {'name': 'Rahul', 'city': 'Delhi'}

# %%
d = {"x": 10, "y": 20, "z": 30}
d.popitem()
# Out:
# ('z', 30)

# %%
original = {"a": 1, "b": 2}
copy = original.copy()
copy
# Out:
# {'a': 1, 'b': 2}

# %%
keys = ["red", "green",  "blue"]
di = dict.fromkeys(keys,10)
di
# Out:
# {'red': 10, 'green': 10, 'blue': 10}

# %%
my_tup = (10,"hello",3.14,True)
# my_tup[1] = "World" ---> error
my_tup
# Out:
# (10, 'hello', 3.14, True)

# %%
d = {"name": "Sumit"}
d.setdefault("age", 25)
d
# Out:
# {'name': 'Sumit', 'age': 25}

# %%
my_dict = {}
my_dict.update({"name":"Abhi"})
my_dict.update({"Age":"21"})
my_dict.update({"City":"Vizag"})
my_dict
# Out:
# {'name': 'Abhi', 'Age': '21', 'City': 'Vizag'}

# %%
A = (1,2,3,4,6,6)
A.index(2)
# Out:
# 1

# %%
A.count(6)
# Out:
# 2

# %%
stu = {}
stu["Abhi"] = 10
stu["Sai"] = 20
stu["Ram"] = 30
stu
# Out:
# {'Abhi': 10, 'Sai': 20, 'Ram': 30}

# %%
# Given data = {"a": 10, "b": 20, "c": 10}, use items() and print only  keys where value is 10. 
data = {"a": 10, "b": 20, "c": 10}
for i in range (3):
    if data.items(i) == 10:
        print("done")
    else:
        print("not done")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 data = {"a": 10, "b": 20, "c": 10}
#       2 for i in range (3):
# ----> 3     if data.items(i) == 10:
#       4         print("done")
#       5     else:
#
# TypeError: dict.items() takes no arguments (1 given)

# %%
data = {"a": 10, "b": 20, "c": 10}
for key,values in data.items():
    if values == 10:
        print("found")
# Out:
# found
# found

# %%
data = {"a": 10, "b": 20, "c": 10, "d": 20, "e": 10}
datac = data.copy()
data.clear()
print(f"data: {data}")
print(f"datac: {datac}")
# Out:
# data: {}
# datac: {'a': 10, 'b': 20, 'c': 10, 'd': 20, 'e': 10}

# %%
datac
# Out:
# {'a': 10, 'b': 20, 'c': 10, 'd': 20, 'e': 10}

# %%
student = {"a": 50, "b": 40, "c": 50, "d": 30}

# %% [markdown]
# # Sets and IF statements

# %%
set1 = {1, 2, 3, 2, 4, 1}
set1
# Out:
# {1, 2, 3, 4}

# %%
set1 = set()
set1.add((1,2))
set1.add(3) # 
set1
# Out:
# {(1, 2), 3}

# %%
s = {10,20,30}
s.update([40,50,60])
s.update([70]) # s.update(70) --> error
s
# Out:
# {10, 20, 30, 40, 50, 60, 70}

# %%
s = {10,20,30,40}
s.remove(20)
# s.remove(50) --> gives error
s
# Out:
# {10, 30, 40}

# %%
s = {10,20,30,40}
s.discard(20)
# s.discard(50) --> does not give error
s
# Out:
# {10, 30, 40}

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}
print(A.union(B))
print(A.intersection(B))
print(A.difference(B))
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}

# %%
s = {10, 20, 30, 40}
if 25 in s:
    print("True")
else:
    print("False")
# Out:
# False

# %%
list1 = [1, 2, 2, 3, 4, 4, 5]
set1 = set(list1)
len(set1)
# Out:
# 5

# %%
set1 = set()
for i in range(5):
    set1.add(input(f"Enter value {i}:"))
set1
# Out:
# Enter value 0: 1
# Enter value 1: 2
# Enter value 2: 2
# Enter value 3: 3
# Enter value 4: 4
# {'1', '2', '3', '4'}

# %%
A = {1, 2, 3}
B = {3, 4, 5}
print(A.difference(B))
# Out:
# {1, 2}

# %%
set1 = {1,2,3}
list1 = [1,2,3]
set1.add(list1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 3
#       1 set1 = {1,2,3}
#       2 list1 = [1,2,3]
# ----> 3 set1.add(list1)
#
# TypeError: unhashable type: 'list'

# %%
age = int(input("Enter your age:"))
if age>=18:
    print("You are eligible to vote")
else:
    print("You are not eligible to vote")
# Out:
# Enter your age: 21
# You are eligible to vote

# %%
number = int(input("Enter a number"))
if number<0:
    print("negative")
elif number>0:
    print("positive")
else:
    print("number is zero")
# Out:
# Enter a number 21
# positive

# %%
a = 21
b = 34
if a>b:
    print("a is big")
elif b>a:
    print("b is big")
else:
    print("both are same")
# Out:
# b is big

# %%
char = (input("Enter char"))
if char=='a' or char=='e' or char=='i' or char=='o' or char=='u':
    print("it is a vowel")
else:
    print("not a vowel")
# Out:
# Enter char b
# not a vowel

# %%
a = int(input("Enter"))
b = int(input("Enter"))
c = int(input("Enter"))
d = int(input("Enter"))
e = int(input("Enter"))

grade = (a+b+c+d+e)/5
if grade>= 90:
    print("A grade")
elif grade>= 80:
    print("B grade")
elif grade>= 70:
    print("C grade")
else:
    print("Fail")
# Out:
# Enter 90
# Enter 80
# Enter 70
# Enter 90
# Enter 90
# B grade

# %%
a = 40
b = 50
c = 60

if a>b and a>c:
    print("a")
elif b>c and b>a:
    print("b")
else:
    print("c")
# Out:
# c

# %%
number = int(input("Enter"))
if number%2==0 and number>50:
    print("True")
elif number%2==0:
    print(f"{number} not greater than 50")
else:
    print(f"{number} is odd")
# Out:
# Enter 65
# 65 is odd

# %%
username = input("enter username")
password = (input("Enter password"))
if username == "admin" and password == "1234":
    print("Login success")
else:
    print("Login failed")
# Out:
# enter username admin
# Enter password 12345
# Login failed

# %%
year = int(input("enter"))
if (year%4==0 and year%100!=0) or year%400==0:
    print(f"{year} is a leap year")
else:
    print(f"{year} is not a leap year")
# Out:
# enter 1900
# 1900 is not a leap year

# %%
a = 21
b = 23
c = 25
if a+b>c and b+c>a and a+c>b:
    print("triangle can be formed")
else:
    print("triangel cannot be formed")
# Out:
# triangle can be formed

# %% [markdown]
# # Flow Control

# %%
number = int(input("Enter :"))
if number >= 0:
    print("positive")
else:
    print("negative")
# Out:
# Enter : -23
# negative

# %%
age = int(input("Enter :"))
if age >= 18:
    print("You can vote")
# Out:
# Enter : 18
# You can vote

# %%
a = int(input("Enter a:"))
b = int(input("Enter b:"))
if a>=b:
    print(f"{a} is larger")
else:
    print(f"{b} is larger")
# Out:
# Enter a: 345
# Enter b: 432
# 432 is larger

# %%
a = int(input("Enter a:"))
if a%2==0:
    print(f"{a} is even")
else:
    print(f"{a} is odd")
# Out:
# Enter a: 20
# 20 is even

# %%
a = (input("Enter:"))
if a == 'A':
    print("it is 'A'")
else:
    print("it is not 'A'")
# Out:
# Enter: A
# it is 'A'

# %%
marks = int(input("Enter marks:"))
if marks >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter marks: 30
# Fail

# %%
number = int(input("Enter number:"))
if number%5 == 0:
    print(f"{number} is divisible by 5")
else:
    print(f"{number} is not divisible by 5")
# Out:
# Enter number: 23
# 23 is not divisible by 5

# %%
number = int(input("Enter:"))
if number > 0:
    print("positive")
elif number < 0:
    print("negative")
else:
    print("zero")
# Out:
# Enter: 0
# zero

# %%
a = 85
b = 95
c = 85
if a>=b and a>=c:
    print(f"{a} is bigger")
elif b>a and b>=c:
    print(f"{b} is bigger")
else:
    print(f"{c} is bigger")
# Out:
# 95 is bigger

# %%
year = int(input("Enter:"))
if (year%4 == 0 and year%100 != 0) or year%400 == 0:
    print(f"{year} is a leap year")
else:
    print(f"{year} is not a leap year")
# Out:
# Enter: 1900
# 1900 is not a leap year

# %%
a = (input("Enter:"))
if a == 'a' or a == 'e' or a == 'i' or a == 'o' or a == 'u':
    print("vowels")
else:
    print("consonant")
# Out:
# Enter: b
# consonant

# %%
salary = int(input("Enter:"))
if salary > 50000:
    print("High")
elif salary > 30000:
    print("medium")
else:
    print("low")
# Out:
# Enter: 45000
# medium

# %%
temp = int(input("Enter:"))
if temp>30:
    print("hot")
elif temp >=20:
    print("warm")
else:
    print("cold")
# Out:
# Enter: 1
# cold

# %%
username = input("enter username")
password = (input("Enter password"))
if username == "admin" and password == "1234":
    print("Login success")
else:
    print("Login failed")
# Out:
# enter username admin
# Enter password 1234
# Login success

# %%
a = 22
b = 21
c = 21
if (a+b>c and b+c>a and a+c>b):
    print("Triangle can be formed, it is ")
    if a == b == c:
        print("Equilateral")
    elif a == b or b == c or a == c:
        print("Isosceles")
    else:
        print("Scalene")
# Out:
# Triangle can be formed, it is
# Isosceles

# %%
s1 = 90
s2 = 50
s3 = 60
s4 = 70
s5 = 80
per = (s1+s2+s3+s4+s5)/5
if per >= 90:
    print("A+")
elif per >= 80:
    print("A")
elif per >= 70:
    print("B")
elif per >= 60:
    print("C")
else:
    print("Fail")
# Out:
# B

# %%
number = int(input("Enter number"))
if number%3 == 0 and number%5 == 0:
    print("FizzBuzz")
elif number%3 == 0:
    print("Fizz")
elif number%5 == 0:
    print("Buzz")
else:
    print(number)
# Out:
# Enter number 3
# Fizz

# %%
age = int(input("Enter"))
gender = input("male/female")
if age >= 18 and gender == "male":
    print("Eligible for Army")
elif age >= 18 and gender == "female":
    print("Eligible for  Other Services")
else:
    print("Not Eligible")
# Out:
# Enter 30
# male/female
# Not Eligible

# %%
a = input("Enter")[0]
if a.isdigit():
    print(f"{a} is number")
elif a.isalpha() and a.islower():
    print(f"{a} is lower")
elif a.isalpha() and a.isupper():
    print(f"{a} is number")
else:
    print(f"{a} is special symbol")
# Out:
# Enter ER
# E is number

# %%
a = 100
b = 20
c = 65

if a<=b and a<=c:
    print(a)
    if b<c:
        print(b)
        print(c)
    else:
        print(c)
        print(b)
elif b<a and b<c:
    print(b)
    if a<c:
        print(a)
        print(c)
    else:
        print(c)
        print(a)
elif c<a and c<b:
    print(c)
    if a<b:
        print(a)
        print(b)
    else:
        print(b)
        print(a)
# Out:
# 20
# 65
# 100

# %% [markdown]
# # 2nd Task

# %%
a = 21
b = 34
c = 56
if a>=b and a>=c:
    print(f"{a} is bigger")
elif b>a and b>=c:
    print(f"{b} is bigger")
else:
    print(f"{c} is bigger")
# Out:
# 56 is bigger

# %%
units = int(input("Enter the units:"))
if units<100:
    print(f"{units*2}")
elif units<=300:
    print(f"{units*4}")
else:
    print(f"{units*6}")
# Out:
# Enter the units: 250
# 1000

# %%
side1 = int(input("Enter"))
side2 = int(input("Enter"))
side3 = int(input("Enter"))
if side1==side2==side3:
    print("Equilateral")
elif side1==side2 or side2==side3:
    print("Isosceles")
else:
    print("Scalene")
# Out:
# Enter 12
# Enter 12
# Enter 12
# Equilateral

# %%
salary = int(input("Enter"))
if salary > 50000:
    print(salary+(salary*(1/5)))
elif salary > 30000:
    print(salary+(salary*(1/10)))
else:
    print(salary+(salary*(1/20)))
# Out:
# Enter 20000
# 21000.0

# %%
username = input("enter username")
password = (input("Enter password"))
if username == "abhi" and password == "0098":
    print("Login success")
else:
    print("Login failed")
# Out:
# enter username abhi
# Enter password 0098
# Login success

# %%
number = int(input("Enter the number:"))
if number%3==0 and number%5==0:
    print(f"{number} is divisible by 3 and 5")
elif number%3 == 0:
    print(f"{number} is divisible by 3")
elif number%5 == 0:
    print(f"{number} is divisible by 5")
else:
    print(f"{number} is not divisible by 3 and 5")
# Out:
# Enter the number: 2
# 2 is not divisible by 3 and 5

# %%
age = int(input("enter"))
if age <= 12:
    print("Child")
elif age <= 19:
    print("teenager")
elif age <= 59:
    print("Adult")
else:
    print("Senior Citizen")
# Out:
# enter 10
# Child

# %%
age = int(input("enter"))
if age<5:
    print("Free")
elif age<18:
    print("₹100")
elif age<60:
    print("₹200")
else:
    print("₹150")
# Out:
# enter 34
# ₹200

# %%
print("Select the service:")
print("1 --> Check balance ")
print("2 --> Withdraw money ")
print("3 --> Deposit money ")

opt = int(input("Enter you service:"))
if opt==1:
    print("check balance")
elif opt==2:
    print("Withdraw money")
elif opt==3:
    print("Deposit money")
else:
    print("Invalid option message")
# Out:
# Select the service:
# 1 --> Check balance
# 2 --> Withdraw money
# 3 --> Deposit money
# Enter you service: 4
# Invalid option message

# %%
inc = int(input("Enter"))
if inc < 250000:
    print("no tax")
elif inc < 500000:
    print(f"{inc*(1/20)}")
elif inc < 1000000:
    print(f"{inc*(1/5)}")
else:
    print(f"{inc*(3/10)}")
# Out:
# Enter 900000
# 180000.0

# %%
a = int(input("Enter a"))
b= int(input("Enter b"))
c= int(input("Enter c"))

delta = (b*b)-(4*a*c)
if delta>0:
    print("roots are real")
elif delta == 0:
    print("roots are equal")
else:
    print("roots are imaginary")
# Out:
# Enter a 3
# Enter b 1
# Enter c 3
# roots are imaginary

# %%
s = str(input("Enter action:"))
a = int(input("Enter"))
b = int(input("Enter"))
if s=="add":
    print(a+b)
elif s=="sub":
    print(a-b)
elif s=="mul":
    print(a*b)
else:
    print(a/b)
# Out:
# Enter action: div
# Enter 6
# Enter 3
# 2.0

# %%
a = int(input("Enter angle 1:"))
b = int(input("Enter angle 2:"))
c = int(input("Enter angle 3:"))
if (a+b+c)==180:
    print("triangle can be formed")
else:
    print("triangle cannot be formed")
# Out:
# Enter angle 1: 60
# Enter angle 2: 60
# Enter angle 3: 60
# triangle can be formed

# %% [markdown]
# # Nested Conditions

# %%
number = int(input("Enter the number"))
if number > 0:
    if number%2 == 0:
        print(f"{number} is even")
    else:
        print(f"{number} is odd")
else:
    print(f"{number} is negative")
# Out:
# Enter the number 8
# 8 is even

# %%
age = int(input("Enter age:"))
if age >= 18:
    if age >= 60:
        print("senior citizen")
    else:
        print("adult")
else:
    print("Not an adult")
# Out:
# Enter age: 2
# Not an adult

# %%
char = input("Enter:")
if char.isalpha():
    if char.islower():
        print(f"{char} is lower")
    else:
        print(f"{char} is upper")
else:
    print(f"{char} is not a alphabetic")
# Out:
# Enter: sdfffg24345565
# sdfffg24345565 is not a alphabetic

# %%
a = 10
b = 30
c = 20

if a>b:
    if a>c:
        print(a)
    else:
        print(c)
else:
    if b>c:
        print(b)
    else:
        print(c)
# Out:
# 30

# %%
marks = int(input("Enter the number"))
if marks >= 40:
    if marks >=75:
        print("Pass with Distinction")
    else:
        print("pass")
else:
    print("Fail")
# Out:
# Enter the number 20
# Fail

# %%
number = int(input("Enter the number"))

if number%2 == 0:
    if number%4 == 0:
        print(f"{number} is both divisible by 2 and 4")
    else:
        print(f"{number} is only divisible by 2")
else:
    print(f"{number} is not divisible by 2 and 4")
# Out:
# Enter the number 4
# 4 is both divisible by 2 and 4

# %%
username = "admin"
password = 1234
user_name = input("enter:")
pas = int(input("Enter"))

if user_name == username:
    if pas == password:
        print("logged in")
    else:
        print("password incorrect")
else:
    print("wrong username")
# Out:
# enter: admin
# Enter 2345
# password incorrect

# %%
a = 21
b = 22
c = 23

if a+b>c and b+c>a and c+a>b:
    if a==b==c :
        print("an eqilateral triangle can be formed")
    elif a==b or b==c or c==a:
        print("an Isosceles triangle can be formed")
    else:
        print("an Scalene triangle can be formed")
else:
    print("triangle cannot be formed")
# Out:
# an Scalene triangle can be formed

# %%
salary = int(input("Enter:"))

if salary > 50_000:
    exp = int(input("Enter the exp:"))
    if exp >= 10:
        print("Senior Manager")
    else:
        print("Manager")
else:
    print("Employee")
# Out:
# Enter: 80000
# Enter the exp: 8
# Manager

# %%
text = input("Enter:")

if text.isalpha():
    
    if text.lower() in ['a','u','i','e','o']:
        print("Vowel")

    else:
        print("consonat")

elif text.isdigit():
    print("its digit")

elif text.isalnum():
    print("its alpha numeric")

else:
    print("special symbol ")
# Out:
# Enter: dsgsg@hdhdgd
# special symbol

# %%
year = int(input("Enter:"))

if year%4 == 0:
    if year%100!=0 or year%400==0:
        print("leap year")
    else:
        print("not a leap year")
else:
    print("not a leap year")
# Out:
# Enter: 2004
# leap year

# %%
temp = int(input("Enter:"))
if temp > 30:
    print("Hot")
else:
    if temp>=20:
        print("warm")
    else:
        print("cold")
# Out:
# Enter: 25
# warm

# %%
a = 10
b = 20
c = 30

if a==b==c:
    print("all are equal")
else:
    if a==b or b==c or c==a:
        print("two numbers are equal")
    else:
        print("none are same")
# Out:
# none are same

# %%
number = int(input("Enter the number"))

if number>0:
    if number%2==0:
        print("number is positive and even")
    else:
        print("number is odd")
else:
    print("number is negative")
# Out:
# Enter the number 22
# number is positive and even

# %%
s1 = 70
s2 = 60
s3 = 80
s4 = 89
s5 = 98

tot_marks = (s1+s2+s3+s4+s5)/5
if tot_marks >= 60:
    if s1>40 and s2>40 and s3>40 and s4>40 and s5>40:
        print("all subjects are above 40")
    else:
        print("not all subjects are above 40")
else:
    print("averge is less than 60")
# Out:
# all subjects are above 40

# %%
user_name = (input("Enter:"))

if user_name=="admin":
    password = (input("Enter:"))
    if password=="1234":
        age = int(input("Enter:"))
        if age>=18:
            print("Login Successful")
        else:
            print("age below 18")
    else:
        print("password incorrect")
else:
    print("username incorrect")
# Out:
# Enter: admin
# Enter: 1234
# Enter: 12
# age below 18

# %%
number = int(input("Enter the number"))

if number%3==0 or number%5==0:
    if number%3==0 and number%5==0:
        print("divisible by 3 and 5")
    elif number%3==0:
        print("Divisible by 3")
    else:
        print("Divisible by 5")
else:
    print("number is not divisible by 3 and 5")
# Out:
# Enter the number 2
# number is not divisible by 3 and 5

# %%
a = 5
b = 3
c = 4

if a+b>c or b+c>a or c+a>b:
    if (a**2)+(b**2)==(c**2) or (a**2)==(b**2)+(c**2) or (a**2)+(c**2)==(b**2):
        print("right-angled  triangle")
    else:
        print("not a right-angled  triangle")
else:
    print("not a triangle")
# Out:
# right-angled  triangle

# %%
char = input("Enter:")[0]

if char == 'A':
    print("Excellent")
elif char == 'B':
    print("Good")
elif char == 'C':
    print("Average")
elif char == 'D':
    print("Below Average")
else:
    print("Fail")
# Out:
# Enter: AS
# Excellent

# %%
income = int(input("Enter:"))

if income >= 10_00_000:
    if income <= 12_00_000:
        print(f"₹{income*(10/100)} tax")
    elif income <= 16_00_000:
        print(f"₹{income*(15/100)} tax")
    elif income <= 20_00_000:
        print(f"₹{income*(20/100)} tax")
    elif income <= 24_00_000:
        print(f"₹{income*(25/100)} tax")
    else:
        print(f"₹{income*(30/100)} tax")
elif income > 5_00_000:
    if income <= 8_00_000:
        print(f"₹{income*(5/100)} tax")
else:
    if income >= 4_00_000:
        print(f"₹{income*(5/100)} tax")
    else:
        print("Low income")
# Out:
# Enter: 10_00_000
# ₹100000.0 tax

# %%
number = int(input("Enter:"))
if number>0:
    if number%3==0 and number%5==0:
        print("FizzBuzz")
    elif number%3==0:
        print("Fizz")
    elif number%5==0:
        print("Buzz")
else:
    print("Negative Number")
# Out:
# Enter: 5
# Buzz

# %%
a = 10
b = 20
c = 33

if a==b==c:
    print("all equal")
else:
    if a>b:
        if a>c:
            print(f"{a}")
            if a%2==0:
                print("it is even")
            else:
                print("it is odd")
        else:
            print(c)
            if c%2==0:
                print("it is even")
            else:
                print("it is odd")
    else:
        if b>c:
            print(b)
            if b%2==0:
                print("it is even")
            else:
                print("it is odd")
        else:
            print(c)
            if c%2==0:
                print("it is even")
            else:
                print("it is odd")
# Out:
# 33
# it is odd

# %%
user_name = (input("Enter:"))

if user_name=="admin":
    password = (input("Enter:"))
    if password=="python123":
        age = int(input("Enter:"))
        if age>=18:
            print("Login Successful")
        else:
            print("You are too young to login")
    else:
        print("Invalid password")
else:
    print("Invalid Username")
# Out:
# Enter: admin
# Enter: python123
# Enter: 12
# You are too young to login

# %%
s1 = 70
s2 = 60
s3 = 80
s4 = 89
s5 = 98

tot_marks = (s1+s2+s3+s4+s5)/5
if tot_marks >= 60:
    if s1>40 and s2>40 and s3>40 and s4>40 and s5>40:
        print("Pass with Good  Performance")
    else:
        print("Pass but Weak in some subjects")
else:
    print("Fail")
# Out:
# Pass with Good  Performance

# %%
a = 21
b = 22
c = 23

if a+b>c and b+c>a and c+a>b:
    if a==b==c :
        print("an eqilateral triangle can be formed")
    elif a==b or b==c or c==a:
        print("an Isosceles triangle can be formed")
    else:
        print("an Scalene triangle can be formed")
else:
    print("triangle cannot be formed")
# Out:
# an Scalene triangle can be formed
