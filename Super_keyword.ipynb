# %%
from abc import ABC, abstractmethod

# %%
# 1
class Shape(ABC):
    
    @abstractmethod
    def area(self):
        pass

    @abstractmethod
    def perimeter(self):
        pass

class Circle(Shape):
    def __init__(self,r):
        self.__R = r

    def area(self):
        return ((3.14)*(self.__R**2))

    def perimeter(self):
        return (2*(3.14)*self.__R)

class Rectangle(Shape):
    def __init__(self,l,b):
        self.__L = l
        self.__B = b

    def area(self):
        return (self.__L*self.__B)

    def perimeter(self):
        return (2*(self.__L+self.__B))

circle = Circle(5)
rec = Rectangle(5,4)
print("Circle:")
print(circle.area())
print(circle.perimeter())

print("\nRectangle:")
print(rec.area())
print(rec.perimeter())
# Out:
# Circle:
# 78.5
# 31.400000000000002
#
# Rectangle:
# 20
# 18

# %%
# 2
class Vehicle(ABC):
    
    @abstractmethod
    def start(self):
        pass

    @abstractmethod
    def stop(self):
        pass

class Car(Vehicle):

    def start(self):
        print("Car starts")

    def stop(self):
        print("car stoped")

class Bike(Vehicle):
    
    def start(self):
        print("bike starts")

    def stop(self):
        print("bike stoped")

car = Car()
bike = Bike()

car.start()
car.stop()

bike.start()
bike.stop()
# Out:
# Car starts
# car stoped
# bike starts
# bike stoped

# %%
# 3
from abc import ABC,abstractmethod

class Animals(ABC):
    @abstractmethod
    def make_sound(self):
        pass

class Cat(Animals):
    
    def make_sound(self):
        print("Meowww !")

class Dog(Animals):
    
    def make_sound(self):
        print("Bark !")

cat = Cat()
dog = Dog()

cat.make_sound()
dog.make_sound()
# Out:
# Meowww !
# Bark !

# %%
# 4
class Payment(ABC):

    @abstractmethod
    def process_payment(self,amount):
        pass

class CreditCardPayment(Payment):

    def process_payment(self,amount):
        print(f"{amount} is credited to your account")

class CashPayment(Payment):
    
    def process_payment(self,amount):
        print(f"{amount} of cash is given")

cc = CreditCardPayment()
cash = CashPayment()

print("Credit card")
cc.process_payment(10_000)
print("Cash")
cash.process_payment(15_000)
# Out:
# Credit card
# 10000 is credited to your account
# Cash
# 15000 of cash is given

# %%
# 5
class Report(ABC):

    @abstractmethod
    def generate_report(self):
        pass

class PDFReport(Report):
    
    def generate_report(self):
        print("generating a PDF report")

class ExcelReport (Report):
    
    def generate_report(self):
        print("generating a ExcelReport ")

pdf = PDFReport()
excel = ExcelReport()

pdf.generate_report()
excel.generate_report()
# Out:
# generating a PDF report
# generating a ExcelReport

# %%
# 6
class BankAccount(ABC):
    
    @abstractmethod
    def calculate_interest(self):
        pass

class SavingsAccount(BankAccount):
    def __init__(self,amount):
        self.__savings=amount
    
    def calculate_interest(self):
        return self.__savings*0.5


sav = SavingsAccount(20_000)
sav.calculate_interest()
# Out:
# 10000.0

# %%
# 7
class Device(ABC):

    @abstractmethod
    def turn_on(self):
        pass

    @abstractmethod
    def turn_off(self):
        pass

class TV(Device):

    def turn_on(self):
        print("TV on")

    def turn_off(self):
        print("TV off")

class Laptop(Device):

    def turn_on(self):
        print("Laptop on")

    def turn_off(self):
        print("Laptop off")

tv = TV()
laptop = Laptop()

tv.turn_on()
tv.turn_off()
print("\n")
laptop.turn_on()
laptop.turn_off()
# Out:
# TV on
# TV off
#
#
# Laptop on
# Laptop off

# %%
# 8
class Employee(ABC):
    
    @abstractmethod
    def calculate_bonus(self):
        pass

class Manager(Employee):
    def __init__(self,amount):
        self.__salary = amount

    def calculate_bonus(self):
        return (self.__salary + (self.__salary*0.1))  

man = Manager(50_000)

man.calculate_bonus()
# Out:
# 55000.0

# %%
# 9
class Transport(ABC):

    @abstractmethod
    def move(self):
        pass

    @abstractmethod
    def fuel_type(self):
        pass

class Car(Transport):

    def move(self):
        print("Car moves")

    def fuel_type(self):
        print("Petrol")

class Train(Transport):

    def move(self):
        print("Train moves")

    def fuel_type(self):
        print("Electricity")


car = Car()
train = Train()

car.move()
car.fuel_type()
print("\n")
train.move()
train.fuel_type()
# Out:
# Car moves
# Petrol
#
#
# Train moves
# Electricity

# %%
# 10
class Notification(ABC):

    @abstractmethod
    def send(self,message):
        pass

class EmailNotification(Notification):

    def send(self,message):
        print("You have an Email")
        print(message)

class SMSNotification(Notification):

    def send(self,message):
        print("You have an SMS")
        print(message)

email = EmailNotification()
sms = SMSNotification()

email.send("email message")
print("\n")
sms.send("sms messae")
# Out:
# You have an Email
# email message
#
#
# You have an SMS
# sms messae

# %%
# 11
class FileHandler(ABC):

    @abstractmethod
    def read(self):
        pass

    @abstractmethod
    def write(self,data):
        pass

class TextFileHandler(FileHandler):

    def read(self):
        print("Reading textfile")

    def write(self,data):
        print("writing....")
        print(data)

class CSVFileHandler(FileHandler):

    def read(self):
        print("Reading CSV file")

    def write(self,data):
        print("writing....")
        print(data)

tx = TextFileHandler()
csv = CSVFileHandler()

tx.read()
tx.write("text")
print("\n")
csv.read()
csv.write("text")
# Out:
# Reading textfile
# writing....
# text
#
#
# Reading CSV file
# writing....
# text

# %%
# 12
class GameCharacter(ABC):
    @abstractmethod
    def attack(self):
        pass

class Warrior(GameCharacter):
    
    def attack(self):
        print("The warrior has attacked!!")

class Mage(GameCharacter):
    
    def attack(self):
        print("The Mage has attacked!!")

warrior = Warrior()
mage = Mage()

warrior.attack()
mage.attack()
# Out:
# The warrior has attacked!!
# The Mage has attacked!!

# %%
# 13
class Calculator(ABC):
    
    @abstractmethod
    def compute(self,a,b):
        pass

class AddCalculator(Calculator):

    def compute(self,a,b):
        return a+b

class MultiplyCalculator(Calculator):

    def compute(self,a,b):
        return a*b


add = AddCalculator()
mul = MultiplyCalculator()
print(add.compute(2,3))
print(mul.compute(3,4))
# Out:
# 5
# 12

# %%
# 14
class Database(ABC):
    
    @abstractmethod
    def connect(self):
        pass

    @abstractmethod
    def query(self,sql):
        pass

class MySQLDatabase(Database):

    def connect(self):
        print("Your connected to MySQLDatabase...")

    def query(self,sql):
        print(f"Query: {sql}")

class MongoDatabase(Database):

    def connect(self):
        print("Your connected to MongoDatabase...")

    def query(self,sql):
        print(f"Query: {sql}")

sql = MySQLDatabase()
md = MongoDatabase()

sql.connect()
sql.query("Select * from Table")
print("\n")
md.connect()
md.query(" db.collection.find()")
# Out:
# Your connected to MySQLDatabase...
# Query: Select * from Table
#
#
# Your connected to MongoDatabase...
# Query:  db.collection.find()

# %%
# 15
class Shape3D(ABC):

    @abstractmethod
    def volume(self):
        pass

    @abstractmethod
    def surface_area(self):
        pass

class Cube(Shape3D):

    def __init__(self,s):
        self.side=s

    def volume(self):
        print(f"volume of the cube is {self.side**3}")

    def surface_area(self):
        print(f"surface area of the cube is {6*(self.side**2)}")

class Sphere(Shape3D):

    def __init__(self,s):
        self.r=s

    def volume(self):
        print(f"volume of the Sphere is {(3.14)*(4/3)*(self.r**3)}")

    def surface_area(self):
        print(f"surface area of the Sphere is {4*(3.14)*(self.r**2)}")

cube = Cube(4)
sphere = Sphere(4)

cube.volume()
cube.surface_area()

sphere.volume()
sphere.surface_area()
# Out:
# volume of the cube is 64
# surface area of the cube is 96
# volume of the Sphere is 267.94666666666666
# surface area of the Sphere is 200.96

# %%
# 16
class Shape(ABC):
    def __init__(self,color):
        self.__Color = color

    @abstractmethod
    def area(self):
        pass

    def colors(self):
        print(self.__Color)

class Circle(Shape):
    def __init__(self,color,rad):
        super().__init__(color)
        self.__R = rad

    def area(self):
        return ((3.14)*(self.__R**2))

circle = Circle("Blue",4)
print(circle.area())
circle.colors()
# Out:
# 50.24
# Blue

# %%
# 17
class Vechile(ABC):
    def __init__(self,brand):
        self.__Brand=brand

    def get_brand(self):
        print(f"Brand of the car is {self.__Brand}")

    @abstractmethod
    def start(self):
        pass

    @abstractmethod
    def stop(self):
        pass

class Car(Vechile):
    def __init__(self,brand):
        super().__init__(brand)

    def start(self):
        print("Car starts")

    def stop(self):
        print("Car Stops")

car = Car("BMW")
car.start()
car.stop()
car.get_brand()
# Out:
# Car starts
# Car Stops
# Brand of the car is BMW

# %%
# 18
class Animals(ABC):

    def __init__(self,name):
        self.__Name=name
    
    @abstractmethod
    def make_sound(self):
        pass

    def get_name(self):
        return (self.__Name)

class Dog(Animals):

    def __init__(self,name):
        super().__init__(name)
    
    def make_sound(self):
        print(f"{self.get_name()} is Barking !!!")


dog = Dog("Chimtu")
dog.make_sound()
# Out:
# Chimtu is Barking !!!

# %%
# 19
class Payment(ABC):

    def __init__(self,amt):
        self.__Amount=amt

    @abstractmethod
    def process_payment(self,amount):
        pass

    def get_amount(self):
        return self.__Amount

class CreditCardPayment(Payment):

    def __init__(self,amt):
        super().__init__(amt)

    def process_payment(self):
        print(f"{self.get_amount()} is credited to your account")

class CashPayment(Payment):

    def __init__(self,amt):
        super().__init__(amt)
    
    def process_payment(self):
        print(f"{self.get_amount()} of cash is given")

cc = CreditCardPayment(20_000)
cash = CashPayment(10_000)

print("Credit card")
cc.process_payment()
print("Cash")
cash.process_payment()
# Out:
# Credit card
# 20000 is credited to your account
# Cash
# 10000 of cash is given

# %%
# 20
class Employee(ABC):

    def __init__(self,name):
        self.__Name=name
    
    @abstractmethod
    def calculate_bonus(self):
        pass

    def get_name(self):
        return (self.__Name)

class Manager(Employee):
    def __init__(self,name,amount):
        super().__init__(name)
        self.__salary = amount

    def calculate_bonus(self):
        return f"After bonus {self.get_name()} gets salary {self.__salary + (self.__salary*0.1)}"

man = Manager("Madhu",50_000)

man.calculate_bonus()
# Out:
# 'After bonus Madhu gets salary 55000.0'

# %%
# 21
class Report(ABC):

    def __init__(self,title):
        self.__Title=title

    def get_title(self):
        return (self.__Title)

    @abstractmethod
    def generate_report(self):
        pass

class PDFReport(Report):

    def __init__(self,title):
        super().__init__(title)
    
    def generate_report(self):
        print(f"generating a PDF report on {self.get_title()}")


pdf = PDFReport("Harry Potter")

pdf.generate_report()
# Out:
# generating a PDF report on Harry Potter

# %%
# 22
class BankAccount(ABC):

    def __init__(self,balance):
        self.__Balance=balance

    def get_balance(self):
        return (self.__Balance)
    
    @abstractmethod
    def calculate_interest(self):
        pass

class SavingsAccount(BankAccount):
    def __init__(self,balance):
        super().__init__(balance)
    
    def calculate_interest(self):
        amount = self.get_balance()
        return amount+(amount*0.05)
        


sav = SavingsAccount(20_000)
sav.calculate_interest()
# Out:
# 21000.0

# %%
# 23
class Device(ABC):

    def __init__(self,brand):
        self.__Brand=brand

    def get_brand(self):
        return (self.__Brand)

    @abstractmethod
    def turn_on(self):
        pass

    @abstractmethod
    def turn_off(self):
        pass


class Laptop(Device):

    def __init__(self,brand):
        super().__init__(brand)

    def turn_on(self):
        print(f"{self.get_brand()} Laptop is on")

    def turn_off(self):
        print(f"{self.get_brand()} Laptop is off")


laptop = Laptop("HP")

laptop.turn_on()
laptop.turn_off()
# Out:
# HP Laptop is on
# HP Laptop is off

# %%
# 24
class Transport(ABC):

    def __init__(self,speed):
        self.__Speed=speed

    def get_speed(self):
        return (self.__Speed)

    @abstractmethod
    def move(self):
        pass

    @abstractmethod
    def fuel_type(self):
        pass

class Car(Transport):

    # def __init__(self,speed):
    #     super().__init__(speed)

    def move(self):
        print(f"Car moves at {self.get_speed()}Km/ph")

    def fuel_type(self):
        print("Petrol")


car = Car(100)

car.move()
car.fuel_type()
# Out:
# Car moves at 100Km/ph
# Petrol

# %%
# 25
class Notification(ABC):

    def __init__(self,recipient):
        self.__Recipient=recipient

    def get_recipient(self):
        return (self.__Recipient)

    @abstractmethod
    def send(self,message):
        pass

class EmailNotification(Notification):

    def __init__(self,recipient):
        super().__init__(recipient)

    def send(self,message):
        print(f"You have an Email from {self.get_recipient()}")
        print(message)

email = EmailNotification("Infosys")

email.send("email message")
# Out:
# You have an Email from Infosys
# email message

# %%
# 26
class Shape(ABC):
    
    def __init__(self,color):
        self.__Color=color

    def get_color(self):
        return (self.__Color)
    
    @abstractmethod
    def area(self):
        pass

    @abstractmethod
    def perimeter(self):
        pass


class Rectangle(Shape):
    def __init__(self,color,l,b):
        super().__init__(color)
        self.__L = l
        self.__B = b

    def area(self):
        return (self.__L*self.__B)

    def perimeter(self):
        return (2*(self.__L+self.__B))


rec = Rectangle("Blue",5,4)

print("\nRectangle:")
print(rec.area())
print(rec.perimeter())
rec.get_color()
# Out:
# Rectangle:
# 20
# 18
# 'Blue'

# %%
# 29
class Calculator(ABC):

    def __init__(self,name):
        self.__Name=name

    def get_name(self):
        return (self.__Name)
    
    @abstractmethod
    def compute(self,a,b):
        pass

class AddCalculator(Calculator):
    def __init__(self,name):
        super().__init__(name)

    def compute(self,a,b):
        return a+b

class MultiplyCalculator(Calculator):
    def __init__(self,name):
        super().__init__(name)

    def compute(self,a,b):
        return a*b


add = AddCalculator("casio")
mul = MultiplyCalculator("casio")
print(add.compute(2,3))
print(mul.compute(3,4))
add.get_name()
# Out:
# 5
# 12
# 'casio'

# %%
# 27
class Employee(ABC):

    def __init__(self,name):
        self.__Name=name
    
    @abstractmethod
    def calculate_bonus(self):
        pass

    def get_name(self):
        return (self.__Name)

class Developer(Employee):
    def __init__(self,name,amount):
        super().__init__(name)
        self.__salary = amount

    def calculate_bonus(self):
        print( f"Before bonus {self.get_name()} gets salary {self.__salary} \nAfter bonus {self.get_name()} gets salary {self.__salary + (self.__salary*0.15)}")

man = Developer("Madhu",50_000)

man.calculate_bonus()
# Out:
# Before bonus Madhu gets salary 50000
# After bonus Madhu gets salary 57500.0

# %%
# 30
class Report(ABC):

    def __init__(self,title):
        self.__Title=title

    def show_header(self):
        return (self.__Title)

    @abstractmethod
    def generate(self):
        pass


class PDFReport(Report):

    def __init__(self,title):
        super().__init__(title)
    
    def generate(self):
        # return self.show_header()
        return super().show_header()

class HTMLReport(Report):

    def __init__(self,title):
        super().__init__(title)
    
    def generate(self):
        # return self.show_header()
        return super().show_header()
        # print(f"generating a PDF report on {self.get_title()}")


pdf = PDFReport("Harry Potter")
html = HTMLReport("Weekly Report")

print(pdf.generate())
html.generate()
# Out:
# Harry Potter
# 'Weekly Report'

# %%
# hard Question - 1

from abc import ABC,abstractmethod

class BankAccount(ABC):
    total_accounts = 0
    def __init__(self,balance):
        self.Balance = balance
        BankAccount.total_accounts += 1

    @abstractmethod
    def calculate_interest(self,amount):
        pass

    def set_balance(self,amt):
        self.Balance +=amt

    @classmethod
    def get_total_accounts(cls):
        return cls.total_accounts

class SavingsAccount(BankAccount):
    SA_min_bal=2_000
    intrest = 0.1

    def __init__(self,amt):
        super().__init__(amt)


    def calculate_interest(self):
        if self.Balance > self.SA_min_bal:
            self.Balance += self.Balance*self.intrest
            print("Calculating Intrest....")
            print(f"balance is {self.Balance}")
        else:
            print("Your account Balance is less than minimum balance")

class CurrentAccount(BankAccount):

    def __init__(self,amt):
        super().__init__(amt)

    overdraft_limit = 5_000
    intrest = 0.1

    def withdraw(self,amt):
        if self.Balance-amt>0:
            self.Balance -= amt
            print(self.Balance)
            print("Transaction is Successfull")
        elif self.Balance - amt < self.overdraft_limit:
            self.Balance = self.Balance-amt
            print(self.Balance)
            print("Transaction is Successfull")
        else:
            print("Amount is exceeding the overdraft limit!!!")
        

    def calculate_interest(self):
        if self.Balance > 0:
            self.Balance += self.Balance*self.intrest
        else:
            print("Your balance is overdraft")

sa1 = SavingsAccount(10_000)
sa1.calculate_interest()
sa2 = SavingsAccount(1_000)
sa2.calculate_interest()
print("\n")
ca1 = CurrentAccount(20_000)
ca1.withdraw(25_000)
ca1.calculate_interest()

BankAccount.get_total_accounts()
# Out:
# Calculating Intrest....
# balance is 11000.0
# Your account Balance is less than minimum balance
#
#
# -5000
# Transaction is Successfull
# Your balance is overdraft
# 3
